# %%
# %pip install pandas openpyxl
import pandas as pd

# %%
# Load the Excel file
# Replace 'your_file.xlsx' with your actual file name or path
df = pd.read_excel('Telco_customer_churn.xlsx', engine='openpyxl')

# Display the first few rows
df.head()
